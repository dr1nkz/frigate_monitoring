# %%
import requests
import json

# %%
response = requests.get(r'http://localhost:5000/api/events').text
response = json.loads(response)
response
# Out:
# [{'box': None,
#   'camera': 'test',
#   'data': {'attributes': [],
#    'box': [0.7138888888888889,
#     0.2791666666666667,
#     0.2722222222222222,
#     0.40625],
#    'region': [0.5555555555555556,
#     0.15208333333333332,
#     0.4444444444444444,
#     0.6666666666666666],
#    'score': 0.78125,
#    'top_score': 0.84375,
#    'type': 'object'},
#   'end_time': 1709670399.929588,
#   'false_positive': None,
#   'has_clip': True,
#   'has_snapshot': False,
#   'id': '1709670281.724647-90p250',
#   'label': 'cup',
#   'plus_id': None,
#   'retain_indefinitely': False,
#   'start_time': 1709670276.724647,
#   'sub_label': None,
#   'thumbnail': '...',
#   'top_score': None,
#   'zones': ['zone_1']},
#  {'box': None,
#   'camera': 'test',
#   'data': {'attributes': [],
#    'box': [0.6861111111111111,
#     0.25625,
#     0.14305555555555555,
#     0.3333333333333333],
#    'region': [0.12916666666666668,
#     0.0,
#     0.7055555555555556,
#     1.0583333333333333],
# ...

# %%
response[0]
# Out:
# {'box': None,
#  'camera': 'test',
#  'data': {'attributes': [],
#   'box': [0.7138888888888889, 0.2791666666666667, 0.2722222222222222, 0.40625],
#   'region': [0.5555555555555556,
#    0.15208333333333332,
#    0.4444444444444444,
#    0.6666666666666666],
#   'score': 0.78125,
#   'top_score': 0.84375,
#   'type': 'object'},
#  'end_time': 1709670399.929588,
#  'false_positive': None,
#  'has_clip': True,
#  'has_snapshot': False,
#  'id': '1709670281.724647-90p250',
#  'label': 'cup',
#  'plus_id': None,
#  'retain_indefinitely': False,
#  'start_time': 1709670276.724647,
#  'sub_label': None,
#  'thumbnail': '...',
#  'top_score': None,
#  'zones': ['zone_1']}

# %%
response[0]
# Out:
# {'box': None,
#  'camera': 'test',
#  'data': {'attributes': [],
#   'box': [0.7138888888888889, 0.2791666666666667, 0.2722222222222222, 0.40625],
#   'region': [0.5555555555555556,
#    0.15208333333333332,
#    0.4444444444444444,
#    0.6666666666666666],
#   'score': 0.78125,
#   'top_score': 0.84375,
#   'type': 'object'},
#  'end_time': 1709670399.929588,
#  'false_positive': None,
#  'has_clip': True,
#  'has_snapshot': False,
#  'id': '1709670281.724647-90p250',
#  'label': 'cup',
#  'plus_id': None,
#  'retain_indefinitely': False,
#  'start_time': 1709670276.724647,
#  'sub_label': None,
#  'thumbnail': '...',
#  'top_score': None,
#  'zones': ['zone_1']}

# %%
response[0]['end_time'] - response[0]['start_time']
# Out:
# 123.20494103431702
