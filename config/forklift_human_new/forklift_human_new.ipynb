# %%
# !pip install -q ultralytics

# %%
# !pip install -U ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 1.6 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 4.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 21.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# %%writefile forklift_person.yaml
# train: train
# val: valid
# test: test
# path: /kaggle/input/forklift-dataset
#
# # Classes
# names:
#   0: 'forklift'  # class names
#   1: 'person'
# Out:
# Writing forklift_person.yaml

# %%
Yolo = YOLO('yolov9c.pt')
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 190MB/s]

# %%
results = Yolo.train(data='./forklift_person.yaml', epochs=50, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Yolo.export(format='onnx', opset=12)
